# %% [markdown]
# ## Day 45 - DIY Solution
# **Q1. Problem Statement: NLP text processing**<br>
# Write a Python program that reads the demotext.txt text file(provided on LMS).The following are the tasks that are to be taken into consideration while
# constructing the solution for text processing using the NLTK library.
# 1.	Load the demotext.txt text file into a variable and then close the file
# 2.	Do word wise tokenization list out generated tokens
# 3.	Transform each token into a small case
# 4.	Remove stop words from the generated token list
# 5.	Remove extra symbols like commas, full stops, and question marks using a regular expression tokenizer and store them in another variable
# 6.	Do bigram and trigram for generated tokens

# %% [markdown]
# **Step-1:** Importing Libraries.

# %%
import nltk
from nltk import word_tokenize

#The download function will help in downloading the corporas present in the nltk library
#nltk.download()

from nltk.corpus import reuters
from nltk.tokenize import RegexpTokenizer

# %%
import nltk
from nltk import word_tokenize

#The download function will help in downloading the corporas present in the nltk library
#nltk.download()

from nltk.corpus import reuters
from nltk.tokenize import RegexpTokenizer

# %% [markdown]
# **Step-2:** Download 'punkt'.

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# **Step-3:** Load given textfile into variable

# %%
f = open("/content/sample_data/demotext.txt", "r")
#read whole file to a string
text = f.read()

#close file
f.close()

print(text)
# Out:
# What is Lorem Ipsum?
#
# Lorem Ipsum is simply dummy text of the printing and
# typesetting industry. Lorem Ipsum has been the industry's
# standard dummy text ever since the 1500s, when an unknown
# printer took a galley of type and scrambled it to make a
# type specimen book. It has survived not only five centuries,
# but also the leap into electronic typesetting,
# remaining essentially unchanged.
#
# It was popularised in the 1960s with the release of Letraset
# sheets containing Lorem Ipsum passages, and more recently
# with desktop publishing software like Aldus PageMaker
# including versions of Lorem Ipsum.

# %% [markdown]
# **Step-4:** Generate token using Word tokenize

# %%
nltk_tokens = nltk.word_tokenize(text)
print (nltk_tokens)
# Out:
# ['What', 'is', 'Lorem', 'Ipsum', '?', 'Lorem', 'Ipsum', 'is', 'simply', 'dummy', 'text', 'of', 'the', 'printing', 'and', 'typesetting', 'industry', '.', 'Lorem', 'Ipsum', 'has', 'been', 'the', 'industry', "'s", 'standard', 'dummy', 'text', 'ever', 'since', 'the', '1500s', ',', 'when', 'an', 'unknown', 'printer', 'took', 'a', 'galley', 'of', 'type', 'and', 'scrambled', 'it', 'to', 'make', 'a', 'type', 'specimen', 'book', '.', 'It', 'has', 'survived', 'not', 'only', 'five', 'centuries', ',', 'but', 'also', 'the', 'leap', 'into', 'electronic', 'typesetting', ',', 'remaining', 'essentially', 'unchanged', '.', 'It', 'was', 'popularised', 'in', 'the', '1960s', 'with', 'the', 'release', 'of', 'Letraset', 'sheets', 'containing', 'Lorem', 'Ipsum', 'passages', ',', 'and', 'more', 'recently', 'with', 'desktop', 'publishing', 'software', 'like', 'Aldus', 'PageMaker', 'including', 'versions', 'of', 'Lorem', 'Ipsum', '.']

# %% [markdown]
# **Step-5:** Convert all tokens into lower case

# %%
#1. Setting all the words in the file to lower case
nltk_tokens = set(w.lower() for w in nltk_tokens)
nltk_tokens
# Out:
# {"'s",
#  ',',
#  '.',
#  '1500s',
#  '1960s',
#  '?',
#  'a',
#  'aldus',
#  'also',
#  'an',
#  'and',
#  'been',
#  'book',
#  'but',
#  'centuries',
#  'containing',
#  'desktop',
#  'dummy',
#  'electronic',
#  'essentially',
#  'ever',
#  'five',
#  'galley',
#  'has',
#  'in',
#  'including',
#  'industry',
#  'into',
#  'ipsum',
#  'is',
#  'it',
#  'leap',
#  'letraset',
#  'like',
#  'lorem',
#  'make',
#  'more',
#  'not',
#  'of',
#  'only',
#  'pagemaker',
#  'passages',
#  'popularised',
#  'printer',
#  'printing',
#  'publishing',
#  'recently',
#  'release',
#  'remaining',
#  'scrambled',
#  'sheets',
#  'simply',
#  'since',
#  'software',
#  'specimen',
#  'standard',
#  'survived',
#  'text',
#  'the',
#  'to',
#  'took',
#  'type',
#  'typesetting',
#  'unchanged',
#  'unknown',
#  'versions',
#  'was',
#  'what',
#  'when',
#  'with'}

# %%
#2.example of stop words
# looking at some of the stopwrods in the corpus
from nltk.corpus import stopwords
stopWords = stopwords.words('english')

# Printing the stopwords
print(stopWords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# **Step-6:** Remove stopwords

# %%
# Importing the corpus of stopwords
# We can use this corpus to exclude all the stopwords from our file
from nltk.corpus import stopwords

# We will form a word list by taking in the words from the file but exclude those words which are stopwords
wordList = [w for w in nltk_tokens if w.lower() not in stopwords.words('english')]
wordList
# Out:
# ['sheets',
#  '?',
#  'dummy',
#  'typesetting',
#  'standard',
#  'versions',
#  '1500s',
#  'software',
#  'pagemaker',
#  'make',
#  'ipsum',
#  'printing',
#  'type',
#  'also',
#  'ever',
#  'unknown',
#  'centuries',
#  ',',
#  '1960s',
#  'galley',
#  'lorem',
#  'industry',
#  'printer',
#  'book',
#  'specimen',
#  'simply',
#  'essentially',
#  'survived',
#  'letraset',
#  'passages',
#  'including',
#  'publishing',
#  'recently',
#  'electronic',
#  'scrambled',
#  "'s",
#  'aldus',
#  'five',
#  'text',
#  'took',
#  'unchanged',
#  '.',
#  'popularised',
#  'desktop',
#  'leap',
#  'release',
#  'remaining',
#  'like',
#  'containing',
#  'since']

# %% [markdown]
# **Step-7:** Remove extra symobls like comma, fullstop and question mark.

# %%
#3. remove extra symobls like comma, fullstop and questionmark.
tokenizer = RegexpTokenizer(r'\w+')
new_token = tokenizer.tokenize(text)
new_token
# Out:
# ['What',
#  'is',
#  'Lorem',
#  'Ipsum',
#  'Lorem',
#  'Ipsum',
#  'is',
#  'simply',
#  'dummy',
#  'text',
#  'of',
#  'the',
#  'printing',
#  'and',
#  'typesetting',
#  'industry',
#  'Lorem',
#  'Ipsum',
#  'has',
#  'been',
#  'the',
#  'industry',
#  's',
#  'standard',
#  'dummy',
#  'text',
#  'ever',
#  'since',
#  'the',
#  '1500s',
#  'when',
#  'an',
#  'unknown',
#  'printer',
#  'took',
#  'a',
#  'galley',
#  'of',
#  'type',
#  'and',
#  'scrambled',
#  'it',
#  'to',
#  'make',
#  'a',
#  'type',
#  'specimen',
#  'book',
#  'It',
#  'has',
#  'survived',
#  'not',
#  'only',
#  'five',
#  'centuries',
#  'but',
#  'also',
#  'the',
#  'leap',
#  'into',
#  'electronic',
#  'typesetting',
#  'remaining',
#  'essentially',
#  'unchanged',
#  'It',
#  'was',
#  'popularised',
#  'in',
#  'the',
#  '1960s',
#  'with',
#  'the',
#  'release',
#  'of',
#  'Letraset',
#  'sheets',
#  'containing',
#  'Lorem',
#  'Ipsum',
#  'passages',
#  'and',
#  'more',
#  'recently',
#  'with',
#  'desktop',
#  'publishing',
#  'software',
#  'like',
#  'Aldus',
#  'PageMaker',
#  'including',
#  'versions',
#  'of',
#  'Lorem',
#  'Ipsum']

# %% [markdown]
# **Step-8:** generate bigram and trigram

# %%
##4. create bigram and trigram
bigrams=list(nltk.bigrams(nltk_tokens))
bigrams
# Out:
# [('sheets', 'in'),
#  ('in', '?'),
#  ('?', 'dummy'),
#  ('dummy', 'typesetting'),
#  ('typesetting', 'with'),
#  ('with', 'standard'),
#  ('standard', 'versions'),
#  ('versions', '1500s'),
#  ('1500s', 'software'),
#  ('software', 'pagemaker'),
#  ('pagemaker', 'make'),
#  ('make', 'ipsum'),
#  ('ipsum', 'been'),
#  ('been', 'printing'),
#  ('printing', 'type'),
#  ('type', 'also'),
#  ('also', 'ever'),
#  ('ever', 'unknown'),
#  ('unknown', 'centuries'),
#  ('centuries', ','),
#  (',', '1960s'),
#  ('1960s', 'has'),
#  ('has', 'galley'),
#  ('galley', 'lorem'),
#  ('lorem', 'industry'),
#  ('industry', 'when'),
#  ('when', 'printer'),
#  ('printer', 'book'),
#  ('book', 'specimen'),
#  ('specimen', 'more'),
#  ('more', 'simply'),
#  ('simply', 'it'),
#  ('it', 'and'),
#  ('and', 'essentially'),
#  ('essentially', 'an'),
#  ('an', 'survived'),
#  ('survived', 'letraset'),
#  ('letraset', 'what'),
#  ('what', 'passages'),
#  ('passages', 'including'),
#  ('including', 'a'),
#  ('a', 'publishing'),
#  ('publishing', 'recently'),
#  ('recently', 'not'),
#  ('not', 'but'),
#  ('but', 'electronic'),
#  ('electronic', 'scrambled'),
#  ('scrambled', 'was'),
#  ('was', "'s"),
#  ("'s", 'into'),
#  ('into', 'aldus'),
#  ('aldus', 'five'),
#  ('five', 'text'),
#  ('text', 'took'),
#  ('took', 'only'),
#  ('only', 'unchanged'),
#  ('unchanged', '.'),
#  ('.', 'popularised'),
#  ('popularised', 'desktop'),
#  ('desktop', 'leap'),
#  ('leap', 'release'),
#  ('release', 'of'),
#  ('of', 'remaining'),
#  ('remaining', 'is'),
#  ('is', 'the'),
#  ('the', 'like'),
#  ('like', 'to'),
#  ('to', 'containing'),
#  ('containing', 'since')]

# %%
trigrams=list(nltk.trigrams(nltk_tokens))
trigrams
# Out:
# [('sheets', 'in', '?'),
#  ('in', '?', 'dummy'),
#  ('?', 'dummy', 'typesetting'),
#  ('dummy', 'typesetting', 'with'),
#  ('typesetting', 'with', 'standard'),
#  ('with', 'standard', 'versions'),
#  ('standard', 'versions', '1500s'),
#  ('versions', '1500s', 'software'),
#  ('1500s', 'software', 'pagemaker'),
#  ('software', 'pagemaker', 'make'),
#  ('pagemaker', 'make', 'ipsum'),
#  ('make', 'ipsum', 'been'),
#  ('ipsum', 'been', 'printing'),
#  ('been', 'printing', 'type'),
#  ('printing', 'type', 'also'),
#  ('type', 'also', 'ever'),
#  ('also', 'ever', 'unknown'),
#  ('ever', 'unknown', 'centuries'),
#  ('unknown', 'centuries', ','),
#  ('centuries', ',', '1960s'),
#  (',', '1960s', 'has'),
#  ('1960s', 'has', 'galley'),
#  ('has', 'galley', 'lorem'),
#  ('galley', 'lorem', 'industry'),
#  ('lorem', 'industry', 'when'),
#  ('industry', 'when', 'printer'),
#  ('when', 'printer', 'book'),
#  ('printer', 'book', 'specimen'),
#  ('book', 'specimen', 'more'),
#  ('specimen', 'more', 'simply'),
#  ('more', 'simply', 'it'),
#  ('simply', 'it', 'and'),
#  ('it', 'and', 'essentially'),
#  ('and', 'essentially', 'an'),
#  ('essentially', 'an', 'survived'),
#  ('an', 'survived', 'letraset'),
#  ('survived', 'letraset', 'what'),
#  ('letraset', 'what', 'passages'),
#  ('what', 'passages', 'including'),
#  ('passages', 'including', 'a'),
#  ('including', 'a', 'publishing'),
#  ('a', 'publishing', 'recently'),
#  ('publishing', 'recently', 'not'),
#  ('recently', 'not', 'but'),
#  ('not', 'but', 'electronic'),
#  ('but', 'electronic', 'scrambled'),
#  ('electronic', 'scrambled', 'was'),
#  ('scrambled', 'was', "'s"),
#  ('was', "'s", 'into'),
#  ("'s", 'into', 'aldus'),
#  ('into', 'aldus', 'five'),
#  ('aldus', 'five', 'text'),
#  ('five', 'text', 'took'),
#  ('text', 'took', 'only'),
#  ('took', 'only', 'unchanged'),
#  ('only', 'unchanged', '.'),
#  ('unchanged', '.', 'popularised'),
#  ('.', 'popularised', 'desktop'),
#  ('popularised', 'desktop', 'leap'),
#  ('desktop', 'leap', 'release'),
#  ('leap', 'release', 'of'),
#  ('release', 'of', 'remaining'),
#  ('of', 'remaining', 'is'),
#  ('remaining', 'is', 'the'),
#  ('is', 'the', 'like'),
#  ('the', 'like', 'to'),
#  ('like', 'to', 'containing'),
#  ('to', 'containing', 'since')]
