# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
df = pd.read_csv("/content/student.csv")

# %%
df.head()
# Out:
#    Math  Statistics  Physics
# 0    48          68       63
# 1    62          81       72
# 2    79          80       78
# 3    76          83       79
# 4    59          64       62

# %%
math = df["Math"].values
stats = df["Statistics"].values
physics = df["Physics"].values

# %%
#math = math.reshape(-1, 1)
#stats = stats.reshape(-1, 1)
#physics = physics.reshape(-1, 1)

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.add_subplot(111, projection='3d')  # preferred modern method

ax.scatter(math, stats, physics, color="r", label="Actual values")

ax.set_xlabel("Math")
ax.set_ylabel("Statistics")
ax.set_zlabel("Physics")
ax.legend()

plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(math, stats, physics, color = "r", label = "Actual values")
ax.set_xlabel("Math")
ax.set_ylabel("Statistics")
ax.set_zlabel("Physics")
ax.legend()
plt.show()

# %%
X = df[["Math", "Statistics"]].values
y= df["Physics"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(X_test, y_test)
# Out:
# 0.8941868880084114

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [0.09682177 0.91959603]
# -2.3451323623281723

# %% [markdown]
# #**Predicted value**

# %%
y_pred = reg.predict(X_test)

# %%
val = {"Actual": y_test, "Predicted":y_pred}

# %%
df1 = pd.DataFrame(val)
df1
# Out:
#      Actual  Predicted
# 0        77  76.306325
# 1        48  40.053950
# 2        70  68.417248
# 3        90  85.550486
# 4        70  66.480813
# ..      ...        ...
# 195      79  73.740759
# 196      85  84.099002
# 197      74  65.851682
# 198      45  46.346100
# 199      78  72.047011
#
# [200 rows x 2 columns]

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.add_subplot(111, projection = "3d")
ax.scatter(X_train[:, 0], X_train[:, 1], y_train, color = 'r', label = "Actual values")
ax.scatter(X_test[:, 0], X_test[:, 1], y_pred, color = "blue", label = "Predicted value" )
ax.set_xlabel("Math")
ax.set_ylabel("Statistics")
ax.set_zlabel("Physics")
ax.legend()
plt.show()

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.add_subplot(111, projection = "3d")
