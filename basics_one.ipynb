# %%
d = int(input().strip())
d = abs(d)
f = d//1000

s = d%10
print("f =",f)
print("s =",s)
res = f + s
print(res)
# Out:
# 11
# f = 0
# s = 1
# 1

# %%
d = int(input().strip())

# %%
d = -20
d = abs(d)
print(d)
# Out:
# 20
