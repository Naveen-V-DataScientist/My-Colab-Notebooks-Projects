# %% [markdown]
# #Name entities

# %%
import nltk
from nltk import ne_chunk
nltk.download('maxnet_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Error loading maxnet_ne_chunker: Package
# [nltk_data]     'maxnet_ne_chunker' not found in index
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
example = "Ferrari is an Italian luxury sports car manufacturer based in Maranello. Founded by Enzo Ferrari in 1939, the company built its first car in 1940."
print(example)
# Out:
# Ferrari is an Italian luxury sports car manufacturer based in Maranello. Founded by Enzo Ferrari in 1939, the company built its first car in 1940.

# %%
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
tokenized = nltk.word_tokenize(example)
tagged = nltk.pos_tag(tokenized)
nameEnt = ne_chunk(tagged)
print(nameEnt)
# Out:
# (S
#   (GPE Ferrari/NNP)
#   is/VBZ
#   an/DT
#   (GPE Italian/JJ)
#   luxury/NN
#   sports/NNS
#   car/NN
#   manufacturer/NN
#   based/VBN
#   in/IN
#   (GPE Maranello/NNP)
#   ./.
#   Founded/VBN
#   by/IN
#   (PERSON Enzo/NNP Ferrari/NNP)
#   in/IN
#   1939/CD
#   ,/,
#   the/DT
#   company/NN
#   built/VBD
#   its/PRP$
#   first/JJ
#   car/NN
#   in/IN
#   1940/CD
#   ./.)

# %% [markdown]
# #Word sense disambigution

# %%
from nltk.corpus import wordnet

# %%
from nltk.wsd import lesk

# %%
sent1 = "She is looking for a match"
sent2 = "Yesterday's Football match was exciting"

# %%
from nltk import word_tokenize

# %%
c1 = lesk(nltk.word_tokenize(sent1), 'match')
c2 = lesk(nltk.word_tokenize(sent2), 'match')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# /usr/local/lib/python3.12/dist-packages/nltk/data.py in find(resource_name, paths)
#     578     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579     raise LookupError(resource_not_found)
#     580
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-2552399959.py in <cell line: 0>()
# ----> 1 c1 = lesk(nltk.word_tokenize(sent1), 'match')
#       2 c2 = lesk(nltk.word_tokenize(sent2), 'match')
#
# /usr/local/lib/python3.12/dist-packages/nltk/wsd.py in lesk(context_sentence, ambiguous_word, pos, synsets, lang)
#      38     context = set(context_sentence)
#      39     if synsets is None:
# ---> 40         synsets = wordnet.synsets(ambiguous_word, lang=lang)
#      41
#      42     if pos:
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     118             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     119
# --> 120         self.__load()
#     121         # This looks circular, but its not, since __load() changes our
#     122         # __class__ to something new:
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/util.py in __load(self)
#      84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#      88         # Load the corpus.
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/util.py in __load(self)
#      79         else:
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#      83                 try:
#
# /usr/local/lib/python3.12/dist-packages/nltk/data.py in find(resource_name, paths)
#     577     sep = "*" * 70
#     578     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579     raise LookupError(resource_not_found)
#     580
#     581
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
c1 = lesk(nltk.word_tokenize(sent1), 'match')
c2 = lesk(nltk.word_tokenize(sent2), 'match')

print(f"Sense of 'match' in sent1: {c1.definition()}")
print(f"Sense of 'match' in sent2: {c2.definition()}")
# Out:
# Sense of 'match' in sent1: a person who is of equal standing with another in a group
# Sense of 'match' in sent2: the score needed to win a match

# %%
print(c1, c1.definition())
# Out:
# Synset('peer.n.01') a person who is of equal standing with another in a group

# %%
print(c2, c2.definition())
# Out:
# Synset('match.n.05') the score needed to win a match
