# %%
# !pip install requests

# %%
import requests as rq
response = rq.get('https://api.github.com/events',data={'key': 'value'})
print(response)
Response = rq.post('https://httpbin.org/post', data={'key': 'value'})
print(Response)
# Out:
# <Response [200]>
# <Response [200]>

# %%
r = rq.put('https://httpbin.org/put', data={'key': 'value'})
re = rq.delete('https://httpbin.org/delete')
res= rq.head('https://httpbin.org/get')
resp = rq.options('https://httpbin.org/get')
print(r)
print(re)
print(res)
print(resp)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
