# %% [markdown]
# #Import Required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install fuzzy-c-means
# Out:
# Requirement already satisfied: fuzzy-c-means in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from fuzzy-c-means) (1.5.2)
# Requirement already satisfied: numpy<2.0.0,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from fuzzy-c-means) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.4 in /usr/local/lib/python3.12/dist-packages (from fuzzy-c-means) (2.11.10)
# Requirement already satisfied: tabulate<0.9.0,>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from fuzzy-c-means) (0.8.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in /usr/local/lib/python3.12/dist-packages (from fuzzy-c-means) (4.67.1)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from fuzzy-c-means) (0.9.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (0.4.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.12/dist-packages (from typer<0.10.0,>=0.9.0->fuzzy-c-means) (8.3.0)

# %%
from fcmeans import FCM

# %% [markdown]
# ##Steps:
#
# - Fix the value of c (number of clusters), and select a value of m (generally 1.25<m<2), and initialize partition matrix U.

# %%
import numpy as np
n_samples = 5000
X = np.concatenate((
    np.random.normal((-2, -2), size=(n_samples, 2)),
    np.random.normal((2, 2), size=(n_samples, 2))
))

# %%
np.random.normal((-2, -2), size=(n_samples, 2))
# Out:
# array([[-2.2463036 , -0.81519625],
#        [-3.1786527 , -2.64575423],
#        [-3.32458568, -3.45151906],
#        ...,
#        [-3.19725146, -1.2170125 ],
#        [-2.28243684, -2.3722936 ],
#        [-2.44216987, -2.78919575]])

# %%
X
# Out:
# array([[-0.70656324, -2.29405193],
#        [-0.66592807, -3.64342659],
#        [-2.85567721, -2.06435108],
#        ...,
#        [ 0.77834384,  0.91882984],
#        [ 2.71872816,  1.71297325],
#        [ 1.54423001,  1.6821252 ]])

# %%
fcm = FCM(n_clusters = 2)
fcm.fit(X)

# %%
fcm.centers
# Out:
# array([[-2.02178753, -2.01725772],
#        [ 2.02858409,  2.01971151]])

# %%
fcm.predict(X)
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
fcm_clusters = fcm.centers
fcm_labels = fcm.predict(X)
fig, axes = plt.subplots(1, 2, figsize=(11, 5))
axes[0].scatter( X[:, 0], X[:, 1], alpha = 0.1)
axes[1].scatter( X[:, 0], X[:, 1], alpha = 0.1, c = fcm_labels)
axes[1].scatter( fcm_clusters[:, 0], fcm_clusters[:, 1], alpha = 0.1,marker = "+", s = 600, c = 'r')
plt.show()

# %%
fcm_labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1])
