# %%
a = float(input("Enter the value:"))
print("float:",a%0.2f)
# Out:
#   File "<ipython-input-2-28502886d1b7>", line 2
#     print("float:",a%0.2f%%)
#                        ^
# SyntaxError: invalid decimal literal
