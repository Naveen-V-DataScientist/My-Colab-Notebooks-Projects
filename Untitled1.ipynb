# %%
a = [1,2,3,4,5,6]
print(a)
a[0]
# Out:
# [1, 2, 3, 4, 5, 6]
# 1

# %%
a[2:5]
# Out:
# [3, 4, 5]

# %%
a.append(1)
a.append(2)
a.append(3)
print(a)
b = (1,2,3,44,5)
print(b)
b.append(35)
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 1, 2, 3, 1, 2, 3]
# (1, 2, 3, 44, 5)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-07a46c3f0c16> in <cell line: 7>()
#       5 b = (1,2,3,44,5)
#       6 print(b)
# ----> 7 b.append(35)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
import pandas as pd
data = {"Name":["kavi","nan", "ravi"],"age": [12,13,15]}
df = pd.DataFrame(data)
df
# Out:
#    Name  age
# 0  kavi   12
# 1   nan   13
# 2  ravi   15

# %%
a = ["kavi","nan", "ravi"]
df1 = pd.Series(a)
df1
# Out:
# 0    kavi
# 1     nan
# 2    ravi
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   13.333333
# std     1.527525
# min    12.000000
# 25%    12.500000
# 50%    13.000000
# 75%    14.000000
# max    15.000000
